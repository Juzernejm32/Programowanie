# %% [markdown]
# Zadanie_1

# %%
false = "Uwielbiam zajęcia z programowania"

# %%
a = false[13:]
print(a)
# Out:
# ęcia z programowania

# %%
b = false[-33:]
print(b)
# Out:
# Uwielbiam zajęcia z programowania

# %%
c = false[1::3]
print(c)
# Out:
# wlazęa oawi

# %% [markdown]
# Zadanie_2

# %%
true = """Czarny to mój ulubiony kolor, niestety, kolor czarny
bardzo szybko spiera się z moich ubrań"""

# %%
sprawdzam=(true.istitle())
print(sprawdzam)
# Out:
# False

# %%
sprawdzam_c = (true.startswith("C"))
print(sprawdzam_c)
# Out:
# True

# %%
true = true.lower()
true = true.replace("czarny","szary",2)
print(true.capitalize())
# Out:
# Szary to mój ulubiony kolor, niestety, kolor szary
# bardzo szybko spiera się z moich ubrań
